# %%
dados_mei = catalog.load("inadimplencia_mei")
# Out:
# [03/21/23 05:18:45] INFO     Loading data from 'inadimplencia_mei' (ParquetDataSet)...          ]8;id=722440;file://C:\Users\vinli\anaconda3\envs\venv_kedro\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=326113;file://C:\Users\vinli\anaconda3\envs\venv_kedro\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\

# %%
dados_mei
# Out:
#          data  valor
# 0  2016-01-01    7.6
# 1  2016-04-01   69.8
# 2  2016-07-01   70.6
# 3  2016-10-01   33.0
# 4  2017-01-01   32.5
# 5  2017-04-01   31.8
# 6  2017-07-01    5.4
# 7  2017-10-01    1.5
# 8  2018-01-01    2.3
# 9  2018-04-01   10.2
# 10 2018-07-01    9.6
# 11 2018-10-01    8.5
# 12 2019-01-01    9.2
# 13 2019-04-01    8.7
# 14 2019-07-01    2.4
# 15 2019-10-01    1.0
# 16 2020-01-01    0.9
# 17 2020-04-01    0.9
# 18 2020-07-01    0.6
# 19 2020-10-01    0.5
# 20 2021-01-01    0.5
# 21 2021-04-01    0.3
# 22 2021-07-01    0.4
# 23 2021-10-01    0.4
# 24 2022-01-01    0.4
# 25 2022-04-01    0.0
# 26 2022-07-01    0.2
